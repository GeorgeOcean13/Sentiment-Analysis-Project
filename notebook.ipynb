# %% [markdown]
# ### This Notebook is Optional ==> Used Only for EDA purposes.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data/IMDB Dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %%
print(df.head())
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
print(df.columns)
# Out:
# Index(['review', 'sentiment'], dtype='object')

# %%
df["sentiment"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        positive
# 1        positive
# 2        positive
# 3        negative
# 4        positive
#            ...
# 49995    positive
# 49996    negative
# 49997    negative
# 49998    negative
# 49999    negative
# Name: sentiment, Length: 50000, dtype: object>

# %%
df.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
sns.countplot(x="sentiment",data=df,palette='Set2')
plt.title("Sentiment Distribution in IMDB Dataset")
plt.show()
# Out:
# C:\Users\91896\AppData\Local\Temp\ipykernel_14664\3033797599.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="sentiment",data=df,palette='Set2')

# %%
df.sample(5,random_state=42)
# Out:
#                                                   review sentiment
# 33553  I really liked this Summerslam due to the look...  positive
# 9427   Not many television shows appeal to quite as m...  positive
# 199    The film quickly gets to a major chase scene w...  negative
# 12447  Jane Austen would definitely approve of this o...  positive
# 39489  Expectations were somewhat high for me when I ...  negative

# %% [markdown]
# ### Dataset Provided by SIR:
# - This dataset will have an accuracy of 68.80% as this dataset contains unbalanced data.

# %%
df = pd.read_csv("data/tweet_sentiment.csv")

# %%
print(df.head())
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative

# %%
print(df.columns)
# Out:
# Index(['textID', 'text', 'selected_text', 'sentiment'], dtype='object')

# %%
print(df['sentiment'].value_counts())
# Out:
# sentiment
# neutral     11118
# positive     8582
# negative     7781
# Name: count, dtype: int64

# %%
print(df.isna().sum())
# Out:
# textID           0
# text             1
# selected_text    1
# sentiment        0
# dtype: int64

# %%
sns.countplot(x="sentiment",data=df,palette='Set2')
plt.title("Sentiment Distribution in Tweet Dataset")
plt.show()
# Out:
# C:\Users\91896\AppData\Local\Temp\ipykernel_14664\1152837781.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="sentiment",data=df,palette='Set2')
